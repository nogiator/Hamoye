# %% [markdown]
# <a href="https://colab.research.google.com/github/nogiator/Hamoye/blob/master/Hamoye_Stage_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import sklearn
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Below is the code to import the data from my google drive

# %%
fuel_ferc_1 = pd.read_csv("/content/drive/My Drive/Colab Notebooks/fuel_ferc1.txt")
fuel_ferc_1.head()
# Out:
#                 record_id  ...  fuel_cost_per_mmbtu
# 0   f1_fuel_1994_12_1_0_7  ...                1.121
# 1  f1_fuel_1994_12_1_0_10  ...                1.120
# 2   f1_fuel_1994_12_2_0_1  ...                1.650
# 3   f1_fuel_1994_12_2_0_7  ...                1.970
# 4  f1_fuel_1994_12_2_0_10  ...                2.570
#
# [5 rows x 11 columns]

# %%
fuel_ferc_1.describe()
# Out:
#        utility_id_ferc1  ...  fuel_cost_per_mmbtu
# count      29523.000000  ...         29523.000000
# mean         118.601836  ...            19.304354
# std           74.178353  ...          2091.540939
# min            1.000000  ...           -41.501000
# 25%           55.000000  ...             1.940000
# 50%          122.000000  ...             4.127000
# 75%          176.000000  ...             7.745000
# max          514.000000  ...        359278.000000
#
# [8 rows x 7 columns]

# %%
series_fuel_qty_burned = fuel_ferc_1['fuel_qty_burned']

# %%
series_fuel_qty_burned.skew(skipna=True)
# Out:
# 15.851495469109503

# %%
series_fuel_qty_burned.kurtosis(skipna=True)
# Out:
# 651.3694501337732

# %%
corr_matrix = fuel_ferc_1.corr()
corr_matrix["fuel_cost_per_unit_burned"].sort_values(ascending=False)
# Out:
# fuel_cost_per_unit_burned       1.000000
# report_year                     0.013599
# fuel_cost_per_unit_delivered    0.011007
# fuel_cost_per_mmbtu            -0.000437
# fuel_mmbtu_per_unit            -0.010034
# fuel_qty_burned                -0.018535
# utility_id_ferc1               -0.037863
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
fuel_ferc_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     29523 non-null  object
#  1   utility_id_ferc1              29523 non-null  int64
#  2   report_year                   29523 non-null  int64
#  3   plant_name_ferc1              29523 non-null  object
#  4   fuel_type_code_pudl           29523 non-null  object
#  5   fuel_unit                     29343 non-null  object
#  6   fuel_qty_burned               29523 non-null  float64
#  7   fuel_mmbtu_per_unit           29523 non-null  float64
#  8   fuel_cost_per_unit_burned     29523 non-null  float64
#  9   fuel_cost_per_unit_delivered  29523 non-null  float64
#  10  fuel_cost_per_mmbtu           29523 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
grouped = fuel_ferc_1.groupby("report_year")
for name, group in grouped:
  print(grouped["fuel_cost_per_unit_delivered"].agg(np.sum))
# Out:
# report_year
# 1994    7.859053e+04
# 1995    3.931506e+04
# 1996    1.000602e+07
# 1997    1.218738e+07
# 1998    3.178799e+05
# 1999    2.682921e+04
# 2000    1.352903e+06
# 2001    8.142834e+04
# 2002    5.735121e+04
# 2003    6.740849e+04
# 2004    1.663129e+05
# 2005    5.258506e+04
# 2006    4.805125e+04
# 2007    5.476283e+04
# 2008    7.194631e+04
# 2009    7.975923e+05
# 2010    1.158381e+05
# 2011    7.412059e+04
# 2012    7.581617e+04
# 2013    2.065968e+05
# 2014    2.256952e+05
# 2015    3.569033e+05
# 2016    1.074344e+05
# 2017    4.587348e+04
# 2018    4.748057e+05
# Name: fuel_cost_per_unit_delivered, dtype: float64
# report_year
# 1994    7.859053e+04
# 1995    3.931506e+04
# 1996    1.000602e+07
# 1997    1.218738e+07
# 1998    3.178799e+05
# 1999    2.682921e+04
# 2000    1.352903e+06
# 2001    8.142834e+04
# 2002    5.735121e+04
# 2003    6.740849e+04
# 2004    1.663129e+05
# 2005    5.258506e+04
# 2006    4.805125e+04
# 2007    5.476283e+04
# ...

# %%
fuel_ferc_1.loc[:, fuel_ferc_1.isnull().any()].columns
# Out:
# Index(['fuel_unit'], dtype='object')
